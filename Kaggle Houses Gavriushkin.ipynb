# %% [markdown]
# # My Evaluation

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import pandas as pd ## pandas is used to manupulate the dataframe
import numpy as np ## numpy is used to do scientific calculations
import matplotlib.pyplot as plt ## matplotlib used for visualization
import seaborn as sns ## seaborn used for visualization 
import missingno as msno ## used to visualize missing values
import warnings ## used to remove warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.model_selection import train_test_split,cross_validate, GridSearchCV
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression,Lasso,Ridge,BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

import math
from IPython.display import Image
import warnings
warnings.filterwarnings("ignore")
sns.set(rc={"figure.figsize": (20, 15)})
sns.set_style("whitegrid")

# %%
df = pd.read_csv('input/train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
df.head(10).style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_8f810_row0_col0, #T_8f810_row0_col18, #T_8f810_row0_col36, #T_8f810_row0_col45, #T_8f810_row0_col48, #T_8f810_row0_col52, #T_8f810_row0_col56, #T_8f810_row0_col66, #T_8f810_row0_col68, #T_8f810_row0_col69, #T_8f810_row0_col70, #T_8f810_row0_col71, #T_8f810_row0_col75, #T_8f810_row1_col1, #T_8f810_row1_col26, #T_8f810_row1_col36, #T_8f810_row1_col44, #T_8f810_row1_col45, #T_8f810_row1_col47, #T_8f810_row1_col50, #T_8f810_row1_col52, #T_8f810_row1_col67, #T_8f810_row1_col68, #T_8f810_row1_col69, #T_8f810_row1_col70, #T_8f810_row1_col71, #T_8f810_row1_col75, #T_8f810_row2_col18, #T_8f810_row2_col36, #T_8f810_row2_col45, #T_8f810_row2_col48, #T_8f810_row2_col52, #T_8f810_row2_col66, #T_8f810_row2_col68, #T_8f810_row2_col69, #T_8f810_row2_col70, #T_8f810_row2_col71, #T_8f810_row2_col75, #T_8f810_row3_col18, #T_8f810_row3_col19, #T_8f810_row3_col26, #T_8f810_row3_col36, #T_8f810_row3_col38, #T_8f810_row3_col45, #T_8f810_row3_col48, #T_8f810_row3_col49, #T_8f810_row3_col50, #T_8f810_row3_col52, #T_8f810_row3_col66, #T_8f810_row3_col69, #T_8f810_row3_col70, #T_8f810_row3_col71, #T_8f810_row3_col75, #T_8f810_row3_col77, #T_8f810_row4_col18, #T_8f810_row4_col36, #T_8f810_row4_col45, #T_8f810_row4_col48, #T_8f810_row4_col52, #T_8f810_row4_col68, #T_8f810_row4_col69, #T_8f810_row4_col70, #T_8f810_row4_col71, #T_8f810_row4_col75, #T_8f810_row5_col17, #T_8f810_row5_col18, #T_8f810_row5_col26, #T_8f810_row5_col36, #T_8f810_row5_col37, #T_8f810_row5_col43, #T_8f810_row5_col45, #T_8f810_row5_col48, #T_8f810_row5_col49, #T_8f810_row5_col51, #T_8f810_row5_col52, #T_8f810_row5_col54, #T_8f810_row5_col56, #T_8f810_row5_col68, #T_8f810_row5_col70, #T_8f810_row5_col71, #T_8f810_row6_col1, #T_8f810_row6_col18, #T_8f810_row6_col36, #T_8f810_row6_col44, #T_8f810_row6_col45, #T_8f810_row6_col48, #T_8f810_row6_col50, #T_8f810_row6_col52, #T_8f810_row6_col68, #T_8f810_row6_col69, #T_8f810_row6_col70, #T_8f810_row6_col71, #T_8f810_row6_col75, #T_8f810_row7_col45, #T_8f810_row7_col48, #T_8f810_row7_col52, #T_8f810_row7_col69, #T_8f810_row7_col70, #T_8f810_row7_col71, #T_8f810_row8_col4, #T_8f810_row8_col18, #T_8f810_row8_col20, #T_8f810_row8_col26, #T_8f810_row8_col34, #T_8f810_row8_col36, #T_8f810_row8_col45, #T_8f810_row8_col47, #T_8f810_row8_col48, #T_8f810_row8_col50, #T_8f810_row8_col59, #T_8f810_row8_col67, #T_8f810_row8_col69, #T_8f810_row8_col70, #T_8f810_row8_col71, #T_8f810_row8_col75, #T_8f810_row9_col3, #T_8f810_row9_col17, #T_8f810_row9_col20, #T_8f810_row9_col26, #T_8f810_row9_col36, #T_8f810_row9_col44, #T_8f810_row9_col45, #T_8f810_row9_col46, #T_8f810_row9_col48, #T_8f810_row9_col49, #T_8f810_row9_col50, #T_8f810_row9_col54, #T_8f810_row9_col61, #T_8f810_row9_col62, #T_8f810_row9_col66, #T_8f810_row9_col68, #T_8f810_row9_col69, #T_8f810_row9_col70, #T_8f810_row9_col71, #T_8f810_row9_col75, #T_8f810_row9_col76, #T_8f810_row9_col80 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col1, #T_8f810_row2_col1, #T_8f810_row4_col1, #T_8f810_row7_col1 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col3, #T_8f810_row1_col4 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col4, #T_8f810_row3_col3 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col17, #T_8f810_row0_col51, #T_8f810_row0_col77, #T_8f810_row1_col51, #T_8f810_row2_col17, #T_8f810_row2_col51, #T_8f810_row2_col77, #T_8f810_row3_col17, #T_8f810_row3_col51, #T_8f810_row4_col77, #T_8f810_row6_col0, #T_8f810_row6_col51, #T_8f810_row7_col17, #T_8f810_row7_col51, #T_8f810_row8_col17, #T_8f810_row8_col77, #T_8f810_row9_col77 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col19 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_8f810_row0_col20 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_8f810_row0_col26 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col34, #T_8f810_row1_col43 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col37 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col38 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col43 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col44 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_8f810_row0_col46 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col47, #T_8f810_row0_col49, #T_8f810_row0_col50, #T_8f810_row1_col18, #T_8f810_row1_col48, #T_8f810_row1_col49, #T_8f810_row1_col66, #T_8f810_row2_col47, #T_8f810_row2_col49, #T_8f810_row2_col50, #T_8f810_row3_col47, #T_8f810_row3_col61, #T_8f810_row3_col68, #T_8f810_row4_col4, #T_8f810_row4_col17, #T_8f810_row4_col26, #T_8f810_row4_col44, #T_8f810_row4_col46, #T_8f810_row4_col47, #T_8f810_row4_col49, #T_8f810_row4_col50, #T_8f810_row4_col51, #T_8f810_row4_col54, #T_8f810_row4_col61, #T_8f810_row4_col62, #T_8f810_row4_col76, #T_8f810_row5_col3, #T_8f810_row5_col47, #T_8f810_row5_col50, #T_8f810_row5_col69, #T_8f810_row5_col75, #T_8f810_row5_col77, #T_8f810_row6_col17, #T_8f810_row6_col19, #T_8f810_row6_col20, #T_8f810_row6_col34, #T_8f810_row6_col38, #T_8f810_row6_col43, #T_8f810_row6_col47, #T_8f810_row6_col49, #T_8f810_row6_col59, #T_8f810_row6_col80, #T_8f810_row7_col36, #T_8f810_row7_col47, #T_8f810_row7_col49, #T_8f810_row7_col50, #T_8f810_row7_col56, #T_8f810_row7_col67, #T_8f810_row7_col77, #T_8f810_row8_col37, #T_8f810_row8_col49, #T_8f810_row8_col52, #T_8f810_row8_col56, #T_8f810_row9_col0, #T_8f810_row9_col1, #T_8f810_row9_col47, #T_8f810_row9_col52, #T_8f810_row9_col56 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8f810_row0_col54, #T_8f810_row8_col54, #T_8f810_row8_col68 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_8f810_row0_col59 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_8f810_row0_col61, #T_8f810_row1_col56, #T_8f810_row1_col61, #T_8f810_row2_col56, #T_8f810_row2_col61, #T_8f810_row3_col54, #T_8f810_row3_col56, #T_8f810_row4_col56, #T_8f810_row5_col61, #T_8f810_row6_col54, #T_8f810_row6_col56, #T_8f810_row6_col61, #T_8f810_row7_col54, #T_8f810_row7_col61, #T_8f810_row7_col75, #T_8f810_row8_col61 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col62, #T_8f810_row1_col38 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col67 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col76, #T_8f810_row3_col76 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_8f810_row0_col80, #T_8f810_row4_col34, #T_8f810_row4_col37 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col0, #T_8f810_row9_col59 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col3, #T_8f810_row6_col66 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_8f810_row1_col17, #T_8f810_row1_col77, #T_8f810_row3_col0, #T_8f810_row6_col77, #T_8f810_row7_col18, #T_8f810_row8_col51, #T_8f810_row9_col18, #T_8f810_row9_col51 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col19, #T_8f810_row7_col26 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col20 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col34, #T_8f810_row6_col3, #T_8f810_row8_col44 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_8f810_row1_col37 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col46 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col54, #T_8f810_row2_col54, #T_8f810_row8_col43, #T_8f810_row9_col38 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col59 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col62 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col76, #T_8f810_row3_col20 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_8f810_row1_col80 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T
# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
var_num = ["SalePrice", "OverallQual", "GrLivArea", "GarageCars", "TotalBsmtSF", "FullBath", "YearBuilt"]
sns.pairplot(df[var_num])

# %%
sns.distplot(df['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df['LogSalePrice'] = np.log10(df['SalePrice'])
sns.distplot(df['LogSalePrice'], color = 'g')
# Out:
# <AxesSubplot:xlabel='LogSalePrice', ylabel='Density'>

# %%
# No duplicated data
df.duplicated().sum()
# Out:
# 0

# %%
pd.options.display.max_rows = None ## Shows all rows, needs to be resetted after
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# LogSalePrice        0
# dtype: int64

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
#resetting the options for 'max_rows'
pd.reset_option('max_rows')

# %% [markdown]
# # Missing values handling

# %% [markdown]
# ### Let's group and see each columns % of missing values

# %%
dfna = df[df.columns[df.isna().any()].tolist()]
a = dfna.isnull().sum()/len(df)*100
a.sort_values(ascending = False, inplace = True)
a
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtExposure     2.602740
# BsmtFinType2     2.602740
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# BsmtQual         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %% [markdown]
# # Let's check, which column values are numeric, to help us further develop data missing values handling strategy

# %% [markdown]
# We make a list of only numeric features

# %%
num = df.select_dtypes(include='number')
numdf = num.columns
numdf
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'LogSalePrice'],
#       dtype='object')

# %% [markdown]
# Let's make a list of numeric and a list of object like data

# %%
numeric = []
objects = []

for i in a.index:
    if i in numdf:
        numeric.append(i)
    else:
        objects.append(i)
print('List of numeric column values: ', numeric)
print('List of objects column values: ', objects)
# Out:
# List of numeric column values:  ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']
# List of objects column values:  ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrType', 'Electrical']

# %% [markdown]
# ## Well done! Now when our data is classifyed both by type and % of missing values, we can group those features and work with those values
# Let's work with first 80% missing data features
#
# Since it's more than 80 percent and data is not numerical, we can drop this features

# %%
df.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'],axis = 1, inplace = True)

# %% [markdown]
# ### Let's work with LotFrontage column, since it's quite unique in range of missing values, while being a numerical feature

# %%
df.LotFrontage.value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: LotFrontage, Length: 110, dtype: int64

# %% [markdown]
# Checking it's distribution will be helpfull for us, so let's visualize it

# %%
sns.distplot(df.LotFrontage)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='Density'>

# %% [markdown]
#  Getting the mean

# %%
df.LotFrontage.mean()
# Out:
# 70.04995836802665

# %% [markdown]
# Checking the percentage of missing values

# %%
print('The percentage of missing data is:', df.LotFrontage.isnull().sum()/len(df)*100 , '%')
# Out:
# The percentage of missing data is: 17.73972602739726 %

# %% [markdown]
# ### Now let's replace missing values with mean, since the percent of missing values is not very high

# %%
df.loc[df.LotFrontage.isnull() == True, 'LotFrontage'] = 70.04995836802665
df.LotFrontage.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Time to get to GarageYrBlt, since it's numerical, let's dive in

# %%
df['GarageYrBlt']
# Out:
# 0       2003.0
# 1       1976.0
# 2       2001.0
# 3       1998.0
# 4       2000.0
#          ...
# 1455    1999.0
# 1456    1978.0
# 1457    1941.0
# 1458    1950.0
# 1459    1965.0
# Name: GarageYrBlt, Length: 1460, dtype: float64

# %%
sns.distplot(df['GarageYrBlt'])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
#Let's find mdeian value to fill the missing data
df['GarageYrBlt'].median()
# Out:
# 1980.0

# %%
#Let's now replace the NaN with median of Garage Year Built
df['GarageYrBlt'].fillna(1980, inplace = True)

# %%
#Let's double check that we applied our changes and also dobule check our NaN values count
print(df.loc[df['GarageYrBlt'] == 1980]['GarageYrBlt'])
print(' Sum of NaN values is: ', df['GarageYrBlt'].isnull().sum())
# Out:
# 39      1980.0
# 48      1980.0
# 78      1980.0
# 88      1980.0
# 89      1980.0
#          ...
# 1349    1980.0
# 1407    1980.0
# 1449    1980.0
# 1450    1980.0
# 1453    1980.0
# Name: GarageYrBlt, Length: 96, dtype: float64
#  Sum of NaN values is:  0

# %% [markdown]
# ## Now let's deal with our last numerical feature 'MasVnrArea'

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 8

# %%
sns.distplot(df['MasVnrArea'])
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='Density'>

# %%
df['MasVnrArea'].median()
# Out:
# 0.0

# %% [markdown]
# ## Important!

# %% [markdown]
# As we can see, the NaN values in MasVnrArea are located, where MasVnrType is 'NA', so it is equal to 0

# %%
df.loc[df['MasVnrArea'].isnull()]['MasVnrArea']
# Out:
# 234    NaN
# 529    NaN
# 650    NaN
# 936    NaN
# 973    NaN
# 977    NaN
# 1243   NaN
# 1278   NaN
# Name: MasVnrArea, dtype: float64

# %%
#Let's replace NaN with 0 (which is also a median)
df.MasVnrArea.fillna(0, inplace = True)

# %% [markdown]
# Let's check our results to make sure we are doing everything correct

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Let's deal with other non-  numerical data

# %% [markdown]
# Before we start, let's make distibution plots, to find outliers and develop a tactic on handling missing values in those features

# %%
f1 = ['FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrType', 'Electrical']
for i in df[f1]:
    plt.figure()
    sns.distplot(df[i].value_counts())

# %% [markdown]
# After observing distributions inequalities and big differences between min and max, let's check the number of each feature class being counted

# %%
for i in df[f1]:
    print(df[i].value_counts())
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %% [markdown]
# Now we can see that 'Electrical', 'BsmtCond', 'BsmtFinType2', 'GarageQual', 'GarageCond' have higly unequal distribution, so we will apply another aproach for those features, instead of just replacing them with 'NA'.
# Let's replace them with the value that is most common for the feature selected

# %%
f2 = ['Electrical', 'BsmtCond', 'BsmtFinType2', 'GarageCond','GarageQual']
#MasVnrtype first
df['Electrical'].fillna('Sbrkr', inplace = True)
#BsmtFinType1
df['BsmtCond'].fillna('TA', inplace = True)
#BsmtExposure
df['BsmtFinType2'].fillna('Unf', inplace = True)
#GarageFinish
df['GarageQual'].fillna('TA', inplace = True)
#GarageQual
df['GarageCond'].fillna('TA', inplace = True)

# %% [markdown]
# Now let's see what other non-numerical features we got left, let's subtract 2 lists and make a new one in order to make no mistake

# %%
f1 = ['FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrType', 'Electrical']
f2 = ['Electrical', 'BsmtCond', 'BsmtFinType2', 'GarageCond','GarageQual']
f3 = []
for i in f1:
    if i not in f2:
        f3.append(i)
print('Features to replace NaN with "NA": ', f3)
# Out:
# Features to replace NaN with "NA":  ['FireplaceQu', 'GarageType', 'GarageFinish', 'BsmtExposure', 'BsmtFinType1', 'BsmtQual', 'MasVnrType']

# %%
#replace chosen features NaN from f3 list above with 'NA'
df[f3] = df[f3].fillna('NA')
#Check the NaN values
df[f3].isnull().sum()
# Out:
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtQual        0
# MasVnrType      0
# dtype: int64

# %%
correlation_m = df[numeric].corr

# %%
df[numeric]
# Out:
#       LotFrontage  GarageYrBlt  MasVnrArea
# 0            65.0       2003.0       196.0
# 1            80.0       1976.0         0.0
# 2            68.0       2001.0       162.0
# 3            60.0       1998.0         0.0
# 4            84.0       2000.0       350.0
# ...           ...          ...         ...
# 1455         62.0       1999.0         0.0
# 1456         85.0       1978.0       119.0
# 1457         66.0       1941.0         0.0
# 1458         68.0       1950.0         0.0
# 1459         75.0       1965.0         0.0
#
# [1460 rows x 3 columns]

# %%
num_feat = []
cat_feat = []

for i in df:
    if i in numdf:
        num_feat.append(i)
    else:
        cat_feat.append(i)
print('List of numeric column values: ', num_feat)
print('\n')
print('List of objects column values: ', cat_feat)
# Out:
# List of numeric column values:  ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'LogSalePrice']
#
#
# List of objects column values:  ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
# Heatmap for all the remaining numerical data including the taget 'SalePrice'
# Define the heatmap parameters
pd.options.display.float_format = "{:,.2f}".format

# Define correlation matrix
corr_matrix = df[num_feat].corr()

# Replace correlation < |0.3| by 0 for a better visibility
corr_matrix[(corr_matrix < 0.3) & (corr_matrix > -0.3)] = 0

# plot the heatmap
sns.heatmap(corr_matrix, vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot_kws={"size": 10, "color": "black"},annot=True)
plt.title("SalePrice Correlation")
# Out:
# Text(0.5, 1.0, 'SalePrice Correlation')

# %% [markdown]
# The highest correlation with SalePrice is observed in GarageCars and GarageArea, GrLivArea,TotalbsmtSF, OverallQual

# %%
corr = df.corr()['SalePrice'].sort_values(ascending = False)[2:10]
corr
# Out:
# OverallQual    0.79
# GrLivArea      0.71
# GarageCars     0.64
# GarageArea     0.62
# TotalBsmtSF    0.61
# 1stFlrSF       0.61
# FullBath       0.56
# TotRmsAbvGrd   0.53
# Name: SalePrice, dtype: float64

# %% [markdown]
# Now we have our Features selected. Let's proceed to EDA

# %% [markdown]
# # Explorational Data Analysis
